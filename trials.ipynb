# %%
from cpp_packages import speed_test

# %%
# %%time
speed_test.sum_of_squares(1_000_000)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# 333332833333500000

# %%
def python_fun(n):
    total = 0
    for i in range(n):
        total += i * i

    print(total)

# %%
# %%time
python_fun(1_000_000)
# Out:
# 333332833333500000
# CPU times: total: 62.5 ms
# Wall time: 74.6 ms
